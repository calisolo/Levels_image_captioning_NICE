# %% [markdown]
# <a href="https://colab.research.google.com/github/kellysolow/OFA-HFeng-NICE/blob/master/data_viewer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from PIL import Image
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
csv_path = './drive/MyDrive/NICE'
result_path= './drive/MyDrive/NICE/output'
val_set = pd.read_csv(f'{csv_path}/nice-val-5k.csv')
valid_caption = pd.read_csv(f'{result_path}/train_on_0406.csv')#validation set
test_caption = pd.read_csv(f'{result_path}/0406_50fit.csv')

#img = Image.open(f'{csv_path}val/{pic_id}.jpg')

# %%
resultDF = test_caption
for index in range(15, 25):
  image_id = resultDF['public_id'][index]
  image = Image.open(f'{csv_path}/cvpr-nice-test/{image_id}.jpg')
  image.show()
  print(resultDF['public_id'][index],resultDF['caption'][index])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x330 at 0x7F77A8A3E5B0>
# 1570541435 View of afire bamboo fence in the wilderness near destructed house
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334 at 0x7F77A978AEB0>
# 1869911456 A portrait shot of a businessman and businesswoman standing at a desk in front of a computer
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334 at 0x7F77A8A01EB0>
# 1578225296 A mid adult woman holding a basket of autumn leaves
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334 at 0x7F77A8A01D90>
# 1572524222 A boy sitting on a father's shoulders riding a wave on a boogie board
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334 at 0x7F77AA1037F0>
# 1297725821 A teenage girl taking a photo with a mobile phone
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334 at 0x7F77A978AEB0>
# 1590209138 View of snowy mountain range with green trees and a small village in the background
# ...
